# %% [markdown]
# # Read in EM Apex data

# %%
# imports
from importlib import reload
import os
import glob

import numpy as np

from scipy.io import loadmat

import gsw

from matplotlib import pyplot as plt

from profiler import floatdata
#from cugn import gliderpairs
#from profiler import utils as cugn_utils
from profiler import binning
from profiler.utils import apex_utils

import pymatreader

# %% [markdown]
# # Load me

# %%
dfile = '/run/user/1000/gvfs/smb-share:server=10.43.20.20,share=cruiseshare/Data/floats/EM_Apex/EMApex_data_small_array_17-Feb-2025.mat'
d = pymatreader.read_mat(dfile)

# %% [markdown]
# ## Notes on the data
#
# ## E = EM Apex (top level)
# ## F10279 = Float #
#
# ## time - datenum
# ## u1, u2, v1, v2 - measured em velocities
# ## U1, U2, V1, V2 - velocities in earth coordinates
# ## u_float, v_float - estimated mean velocity while profiling
# ## time_prof - mean time of profile
# ## lat, lon - estimated mean location of profile
# ## prof_num - odd numbers are down profiles, even are up profiles
# ## te
# ## sa
# ## pr

# %%
d['E']['F10279'].keys()
# Out:
# dict_keys(['U1', 'pr', 'v_float', 'time_prof', 'v2', 'U2', 'lat', 'v1', 'u2', 'prof_num', 'te', 'u1', 'lon', 'u_float', 'V1', 'time', 'V2', 'sa'])

# %%
d['E']['F10279']['pr'].shape
# Out:
# (61, 320)

# %%
d['E']['F10279']['pr'][:,0]
# Out:
# array([  8.356     ,  11.4075    ,  14.57625   ,  18.33666667,
#         22.28333333,  26.20076923,  30.18666667,  34.505     ,
#         38.35692308,  42.3525    ,  45.736875  ,  48.758125  ,
#         52.1925    ,  55.65230769,  58.825625  ,  62.035     ,
#         65.5275    ,  68.84      ,  72.11875   ,  75.72538462,
#         79.81230769,  83.73230769,  87.62      ,  91.2225    ,
#         94.64764706,  98.155     , 101.52916667, 105.26352941,
#        108.674375  , 111.89217391, 114.8152381 , 117.585     ,
#        120.20952381, 122.72857143, 125.43052632, 128.13263158,
#        130.915625  , 133.935625  , 137.07526316, 140.124375  ,
#        143.92533333, 147.63692308, 151.2125    , 155.02923077,
#        158.57764706, 162.20230769, 165.89230769, 169.32636364,
#        172.74214286, 175.72      , 178.70647059, 181.28769231,
#        183.63      , 185.75      ,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan])

# %% [markdown]
# # Process

# %%
reload(apex_utils)
d = apex_utils.process_apex_floats(dfile)
# Out:
# Working on float F10279
# Working on float F10280
# Working on float F10278
# Working on float F10285
# Working on float F10283
# Working on float F10281
# Working on float F10282

# %%
d['F10279'].keys()
# Out:
# dict_keys(['U1', 'pr', 'v_float', 'v2', 'U2', 'lat', 'v1', 'u2', 'prof_num', 'u1', 'lon', 'u_float', 'V1', 'time', 'V2', 't', 's', 'z', 'SA', 'theta', 'sigma', 'rho'])

# %% [markdown]
# # Bin me

# %%
reload(binning)
bindata = binning.run(d['F10279'], add_vel=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 2
#       1 reload(binning)
# ----> 2 bindata = binning.run(d['F10279'], add_vel=False)
#
# File ~/Projects/Oceanography/python/profiler/profiler/binning.py:87, in run(data, pmin, pstep, pmax, pd, exclude, add_vel)
#      85 for n in range(nt):  # Loop on profiles
#      86     if data[pstrdata][n] is not None and len(data[pstrdata][n]) > 0:
# ---> 87         ibin = np.round((data[pstrdata][n] - pmin) / pstep).astype(int)
#      89         # Loop on bins
#      90         for m in range(np_bins):
#
# TypeError: unsupported operand type(s) for -: 'list' and 'int'

# %% [markdown]
# ----
